# %% [markdown]
# <a href="https://colab.research.google.com/github/silvatiagobarbosa/ML/blob/main/alura_ml_recomendacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
filmes = pd.read_csv("movies.csv")
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
filmes.columns = ["filmeId", "titulo", "generos"]
filmes = filmes.set_index("filmeId")
filmes.head()
# Out:
#                                      titulo  \
# filmeId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
#
#                                              generos
# filmeId
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2                         Adventure|Children|Fantasy
# 3                                     Comedy|Romance
# 4                               Comedy|Drama|Romance
# 5                                             Comedy

# %%
notas = pd.read_csv("ratings.csv")
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas.columns = ["usuarioId", "filmeId", "nota", "momento"]
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas.describe()
# Out:
#            usuarioId        filmeId           nota       momento
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %% [markdown]
# # Primeiro Modelo
# Modelo baseado nos filmes mais vistos

# %%
total_de_votos = notas["filmeId"].value_counts()
total_de_votos.head()
# Out:
# filmeId
# 356     329
# 318     317
# 296     307
# 593     279
# 2571    278
# Name: count, dtype: int64

# %%
filmes['total_de_votos'] = total_de_votos
filmes.head()
# Out:
#                                      titulo  \
# filmeId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
#
#                                              generos  total_de_votos
# filmeId
# 1        Adventure|Animation|Children|Comedy|Fantasy           215.0
# 2                         Adventure|Children|Fantasy           110.0
# 3                                     Comedy|Romance            52.0
# 4                               Comedy|Drama|Romance             7.0
# 5                                             Comedy            49.0

# %%
filmes.sort_values("total_de_votos", ascending=False).head(10)
# Out:
#                                             titulo  \
# filmeId
# 356                            Forrest Gump (1994)
# 318               Shawshank Redemption, The (1994)
# 296                            Pulp Fiction (1994)
# 593               Silence of the Lambs, The (1991)
# 2571                            Matrix, The (1999)
# 260      Star Wars: Episode IV - A New Hope (1977)
# 480                           Jurassic Park (1993)
# 110                              Braveheart (1995)
# 589              Terminator 2: Judgment Day (1991)
# 527                        Schindler's List (1993)
#
#                                   generos  total_de_votos
# filmeId
# 356              Comedy|Drama|Romance|War           329.0
# 318                           Crime|Drama           317.0
# 296           Comedy|Crime|Drama|Thriller           307.0
# 593                 Crime|Horror|Thriller           279.0
# 2571               Action|Sci-Fi|Thriller           278.0
# ...

# %%
#Bom, mas trouxe filmes com notas medias

# %% [markdown]
# #Segundo Modelo
# Modelo baseado na nota média

# %%
notas_medias = notas.groupby("filmeId").mean()["nota"]
filmes["nota_media"] = notas_medias
filmes.sort_values("nota_media", ascending=False).head(10)
# Out:
#                                             titulo                   generos  \
# filmeId
# 88448        Paper Birds (Pájaros de papel) (2010)              Comedy|Drama
# 100556                  Act of Killing, The (2012)               Documentary
# 143031                             Jump In! (2007)      Comedy|Drama|Romance
# 143511                                Human (2015)               Documentary
# 143559                         L.A. Slasher (2015)      Comedy|Crime|Fantasy
# 6201                              Lady Jane (1986)             Drama|Romance
# 102217              Bill Hicks: Revelations (1993)                    Comedy
# 102084                Justice League: Doom (2012)   Action|Animation|Fantasy
# 6192     Open Hearts (Elsker dig for evigt) (2002)                   Romance
# 145994                      Formula of Love (1984)                    Comedy
#
#          total_de_votos  nota_media
# filmeId
# 88448               1.0         5.0
# ...

# %%
#Ruim, pois trouxe filmes que so têm uma nota

# %%
filmes_bons_e_populares = filmes.query("total_de_votos >= 40").sort_values("nota_media", ascending=False)
filmes_bons_e_populares.head(10)
#filtrando filmes com meos de 40 avaliações. Talvez seja necessário balancear o filtro para tirar filmes de nicho
# Out:
#                                                     titulo  \
# filmeId
# 318                       Shawshank Redemption, The (1994)
# 1204                             Lawrence of Arabia (1962)
# 858                                  Godfather, The (1972)
# 2959                                     Fight Club (1999)
# 1276                                 Cool Hand Luke (1967)
# 750      Dr. Strangelove or: How I Learned to Stop Worr...
# 904                                     Rear Window (1954)
# 1221                        Godfather: Part II, The (1974)
# 48516                                 Departed, The (2006)
# 1213                                     Goodfellas (1990)
#
#                              generos  total_de_votos  nota_media
# filmeId
# 318                      Crime|Drama           317.0    4.429022
# 1204             Adventure|Drama|War            45.0    4.300000
# 858                      Crime|Drama           192.0    4.289062
# ...

# %% [markdown]
# #Terceiro modelo
# Modelo baseado nos generos de filmes assistidos

# %%
assistidos = [1,21,19,10,11,7,2]
filmes.loc[assistidos]
# Out:
#                                         titulo  \
# filmeId
# 1                             Toy Story (1995)
# 21                           Get Shorty (1995)
# 19       Ace Ventura: When Nature Calls (1995)
# 10                            GoldenEye (1995)
# 11              American President, The (1995)
# 7                               Sabrina (1995)
# 2                               Jumanji (1995)
#
#                                              generos  total_de_votos  \
# filmeId
# 1        Adventure|Animation|Children|Comedy|Fantasy           215.0
# 21                             Comedy|Crime|Thriller            89.0
# 19                                            Comedy            88.0
# 10                         Action|Adventure|Thriller           132.0
# 11                              Comedy|Drama|Romance            70.0
# 7                                     Comedy|Romance            54.0
# 2                         Adventure|Children|Fantasy           110.0
#
# ...

# %%
aventura_infantil_fantasia = filmes_bons_e_populares.query("generos=='Adventure|Children|Fantasy'")
aventura_infantil_fantasia.drop(assistidos, errors='ignore').sort_values("nota_media", ascending=False).head(10)
#filtrando
# Out:
#                                                     titulo  \
# filmeId
# 4896     Harry Potter and the Sorcerer's Stone (a.k.a. ...
# 2161                         NeverEnding Story, The (1984)
# 41566    Chronicles of Narnia: The Lion, the Witch and ...
#
#                             generos  total_de_votos  nota_media
# filmeId
# 4896     Adventure|Children|Fantasy           107.0    3.761682
# 2161     Adventure|Children|Fantasy            43.0    3.581395
# 41566    Adventure|Children|Fantasy            62.0    3.443548

# %% [markdown]
# #Quarto Modelo
# Modelo baseado em similaridade/distancia

# %%
#Distancia entre usuariso 1 e usuario 4. Teste

# %%
import numpy as np

# %%
def notas_usuario(usuario):
    notas_usuario = notas.query("usuarioId==%d" % usuario)
    notas_usuario = notas_usuario[["filmeId","nota"]].set_index("filmeId")
    return notas_usuario

# %%
notas_usuario(4)
# Out:
#          nota
# filmeId
# 21        3.0
# 32        2.0
# 45        3.0
# 47        2.0
# 52        3.0
# ...       ...
# 4765      5.0
# 4881      3.0
# 4896      4.0
# 4902      4.0
# 4967      5.0
#
# [216 rows x 1 columns]

# %%
usuario1 = notas_usuario(1)
usuario4 = notas_usuario(4)

# %%
usuario1.head()
# Out:
#          nota
# filmeId
# 1         4.0
# 3         4.0
# 6         4.0
# 47        5.0
# 50        5.0

# %%
usuario4.head()
# Out:
#          nota
# filmeId
# 21        3.0
# 32        2.0
# 45        3.0
# 47        2.0
# 52        3.0

# %%
diferencas = usuario1.join(usuario4, lsuffix="_esquerda", rsuffix="_direita").dropna()

# %%
def distancia_de_vetores(a,b):
  return np.linalg.norm(a - b)

# %%
distancia_de_vetores(diferencas['nota_esquerda'], diferencas['nota_direita'])
# Out:
# 11.135528725660043

# %%
def distancia_de_usuarios(usuario_id1, usuario_id2):
  notas1 = notas_usuario(usuario_id1)
  notas2 = notas_usuario(usuario_id2)
  diferencas = notas1.join(notas2, lsuffix="_esquerda", rsuffix="_direita").dropna()
  distancia =  distancia_de_vetores(diferencas['nota_esquerda'], diferencas['nota_direita'])
  return [usuario_id1, usuario_id2, distancia]

# %%
distancia_de_usuarios(1,4)
# Out:
# [1, 4, 11.135528725660043]

# %%
#Distancia entre o usuario 1 e todos

# %%
def distancia_de_todos(voce_id):
  distancias = []
  for usuario_id in notas['usuarioId'].unique():
    informacoes = distancia_de_usuarios(voce_id, usuario_id)
    distancias.append(informacoes)
  return distancias

distancia_de_todos(1)[:5]
# Out:
# [[1, 1, 0.0],
#  [1, 2, 1.4142135623730951],
#  [1, 3, 8.200609733428363],
#  [1, 4, 11.135528725660043],
#  [1, 5, 3.7416573867739413]]

# %%
distancia_de_todos(1)[:5]
# Out:
# [[1, 1, 0.0],
#  [1, 2, 1.4142135623730951],
#  [1, 3, 8.200609733428363],
#  [1, 4, 11.135528725660043],
#  [1, 5, 3.7416573867739413]]

# %%
def distancia_de_todos(voce_id):
  todos_os_usuarios = notas['usuarioId'].unique()
  distancias = [distancia_de_usuarios(voce_id, usuario_id) for usuario_id in todos_os_usuarios]
  distancias = pd.DataFrame(distancias, columns = ["voce", "outra_pessoa", "distancia"])
  return distancias

distancia_de_todos(1).head()
# Out:
#    voce  outra_pessoa  distancia
# 0     1             1   0.000000
# 1     1             2   1.414214
# 2     1             3   8.200610
# 3     1             4  11.135529
# 4     1             5   3.741657

# %%
# Usuários sem filmes em comum são colocados bem distante um do outro

# %%
def distancia_de_usuarios(usuario_id1, usuario_id2, minimo = 5):
  notas1 = notas_usuario(usuario_id1)
  notas2 = notas_usuario(usuario_id2)
  diferencas = notas1.join(notas2, lsuffix="_esquerda", rsuffix="_direita").dropna()

  if(len(diferencas) < minimo):
    return [usuario_id1, usuario_id2, 100000]

  distancia =  distancia_de_vetores(diferencas['nota_esquerda'], diferencas['nota_direita'])
  return [usuario_id1, usuario_id2, distancia]

# %%
def mais_proximos_de(voce_id):
  distancias = distancia_de_todos(voce_id)
  distancias = distancias.sort_values("distancia")
  distancias = distancias.set_index("outra_pessoa").drop(voce_id)
  return distancias

# %%
mais_proximos_de(1).head()
# Out:
#               voce  distancia
# outra_pessoa
# 77               1   0.000000
# 511              1   0.500000
# 366              1   0.707107
# 523              1   1.000000
# 49               1   1.000000

# %% [markdown]
# #KNN
# Modelo de similaridade/distancia, mas com número restrito de usuarios e não com todo mundo.
# Conforme é passado um valor por parâmetro, o algoritmo KNN identifica o vizinho mais próximo e faz uma busca de valores parecidos que estejam próximos.

# %%
def mais_proximos_de(voce_id, n = None):
  distancias = distancia_de_todos(voce_id, n = n)
  distancias = distancias.sort_values("distancia")
  distancias = distancias.set_index("outra_pessoa").drop(voce_id)
  return distancias

# %%
def distancia_de_todos(voce_id, n = None):
  todos_os_usuarios = notas['usuarioId'].unique()
  if n:
    todos_os_usuarios = todos_os_usuarios[:n]
  distancias = [distancia_de_usuarios(voce_id, usuario_id) for usuario_id in todos_os_usuarios]
  distancias = pd.DataFrame(distancias, columns = ["voce", "outra_pessoa", "distancia"])
  return distancias

# %%
mais_proximos_de(1, n = 50)
# Out:
#               voce      distancia
# outra_pessoa
# 49               1       1.000000
# 9                1       1.000000
# 13               1       1.414214
# 25               1       1.414214
# 30               1       1.802776
# 35               1       2.236068
# 26               1       2.236068
# 46               1       3.316625
# 8                1       3.741657
# 44               1       3.741657
# 5                1       3.741657
# 37               1       4.000000
# 48               1       4.123106
# 11               1       4.242641
# 24               1       4.415880
# 29               1       4.555217
# 31               1       4.582576
# 17               1       4.609772
# 43               1       4.795832
# 14               1       5.000000
# 32               1       5.196152
# 22               1       5.244044
# 23               1       5.408327
# 38               1       5.567764
# 15               1       5.852350
# 33               1       5.916080
# ...

# %%
def distancia_de_usuarios(usuario_id1, usuario_id2, minimo = 5):
  notas1 = notas_usuario(usuario_id1)
  notas2 = notas_usuario(usuario_id2)
  diferencas = notas1.join(notas2, lsuffix="_esquerda", rsuffix="_direita").dropna()

  if(len(diferencas) < minimo):
    return None

  distancia =  distancia_de_vetores(diferencas['nota_esquerda'], diferencas['nota_direita'])
  return [usuario_id1, usuario_id2, distancia]

# %%
# n significa numero de usuarios a analisar

# %%
def distancia_de_todos(voce_id, n = None):
  todos_os_usuarios = notas['usuarioId'].unique()
  if n:
    todos_os_usuarios = todos_os_usuarios[:n]
  distancias = [distancia_de_usuarios(voce_id, usuario_id) for usuario_id in todos_os_usuarios]
  distancias = list(filter(None, distancias))
  distancias = pd.DataFrame(distancias, columns = ["voce", "outra_pessoa", "distancia"])
  return distancias

# %%
mais_proximos_de(4, n = 20)
# Out:
#               voce  distancia
# outra_pessoa
# 12               4   4.123106
# 11               4   4.582576
# 15               4   5.000000
# 8                4   5.385165
# 7                4   5.634714
# 10               4   5.744563
# 13               4   5.830952
# 20               4   6.144103
# 5                4   6.324555
# 14               4   6.855655
# 17               4   7.810250
# 6                4   8.426150
# 16               4   8.485281
# 18               4  10.404326
# 1                4  11.135529
# 19               4  14.035669

# %%
def sugere_para(voce, n = None):
  notas_de_voce = notas_usuario(voce)
  filmes_que_voce_ja_viu = notas_de_voce.index

  similares = mais_proximos_de(voce, n = n)
  similar = similares.iloc[0].name
  notas_do_similar = notas_usuario(similar)
  notas_do_similar = notas_do_similar.drop(filmes_que_voce_ja_viu, errors='ignore')
  recomendacoes = notas_do_similar.sort_values("nota", ascending=False)
  return recomendacoes.join(filmes)

# %%
sugere_para(4).head()
# Out:
#          nota                                             titulo  \
# filmeId
# 1673      5.0                               Boogie Nights (1997)
# 750       5.0  Dr. Strangelove or: How I Learned to Stop Worr...
# 1252      4.5                                   Chinatown (1974)
# 471       4.0                        Hudsucker Proxy, The (1994)
# 5952      4.0      Lord of the Rings: The Two Towers, The (2002)
#
#                                   generos  total_de_votos  nota_media
# filmeId
# 1673                                Drama            39.0    4.076923
# 750                            Comedy|War            97.0    4.268041
# 1252     Crime|Film-Noir|Mystery|Thriller            59.0    4.211864
# 471                                Comedy            40.0    3.550000
# 5952                    Adventure|Fantasy           188.0    4.021277

# %%
#Mo trecho acima pegamos apenas o mais similar, agora vamos pegaer os n (alguns) mais próximos.

# %%
def mais_proximos_de(voce_id, n_mais_proximos =10,n = None):
  distancias = distancia_de_todos(voce_id, n = n)
  distancias = distancias.sort_values("distancia")
  distancias = distancias.set_index("outra_pessoa").drop(voce_id)
  return distancias.head(n_mais_proximos)

# %%
mais_proximos_de(1,n_mais_proximos=5, n=200)
# Out:
#               voce  distancia
# outra_pessoa
# 77               1   0.000000
# 49               1   1.000000
# 9                1   1.000000
# 65               1   1.322876
# 162              1   1.414214

# %%
def sugere_para(voce, n_mais_proximos = 10, n = None):
  notas_de_voce = notas_usuario(voce)
  filmes_que_voce_ja_viu = notas_de_voce.index

  similares = mais_proximos_de(voce, n_mais_proximos = n_mais_proximos, n = n)
  usuarios_similares = similares.index
  notas_dos_similares = notas.set_index("usuarioId").loc[usuarios_similares]
  recomendacoes = notas_dos_similares.groupby("filmeId").mean()[["nota"]]
  recomendacoes = recomendacoes.sort_values("nota", ascending=False)
  return recomendacoes.join(filmes)

# %%
sugere_para(4, n = 300).head()
# Out:
#          nota                     titulo  \
# filmeId
# 1         5.0           Toy Story (1995)
# 838       5.0                Emma (1996)
# 912       5.0          Casablanca (1942)
# 908       5.0  North by Northwest (1959)
# 906       5.0            Gaslight (1944)
#
#                                              generos  total_de_votos  \
# filmeId
# 1        Adventure|Animation|Children|Comedy|Fantasy           215.0
# 838                             Comedy|Drama|Romance            30.0
# 912                                    Drama|Romance           100.0
# 908        Action|Adventure|Mystery|Romance|Thriller            57.0
# 906                                   Drama|Thriller             7.0
#
#          nota_media
# filmeId
# 1          3.920930
# 838        3.916667
# 912        4.240000
# 908        4.184211
# 906        4.142857

# %%
#Filtrando filmes com mais de 50 views, para desconsiderar filmes de nicho

# %%
notas = notas.set_index("filmeId").loc[filmes_bons_e_populares.index]
notas.head()
# Out:
#          usuarioId  nota     momento
# filmeId
# 318              2   3.0  1445714835
# 318              5   3.0   847434880
# 318              6   5.0   845553200
# 318              8   5.0   839463489
# 318             11   4.0   902155070

# %%
notas = notas.reset_index()

# %%
def sugere_para(voce, k_mais_proximos = 10, n = None):
  notas_de_voce = notas_usuario(voce)
  filmes_que_voce_ja_viu = notas_de_voce.index

  similares = knn(voce, k_mais_proximos = k_mais_proximos, n = n)
  usuarios_similares = similares.index
  notas_dos_similares = notas.set_index("usuarioId").loc[usuarios_similares]
  recomendacoes = notas_dos_similares.groupby("filmeId").mean()[["nota"]]
  aparicoes = notas_dos_similares.groupby("filmeId").count()[['nota']]

  filtro_minimo = k_mais_proximos / 2
  recomendacoes = recomendacoes.join(aparicoes, lsuffix="_media_dos_usuarios", rsuffix="_aparicoes_nos_usuarios")
  recomendacoes = recomendacoes.query("nota_aparicoes_nos_usuarios >= %.2f" % filtro_minimo)
  recomendacoes = recomendacoes.sort_values("nota_media_dos_usuarios", ascending=False)
  recomendacoes = recomendacoes.drop(filmes_que_voce_ja_viu,errors='ignore')
  return recomendacoes.join(filmes)

# %%
def knn(voce_id, k_mais_proximos=10, n = None):
  distancias = distancia_de_todos(voce_id, n = n)
  distancias = distancias.sort_values("distancia")
  distancias = distancias.set_index("outra_pessoa").drop(voce_id, errors='ignore')
  return distancias.head(k_mais_proximos)


sugere_para(4, n=500)
# Out:
#          nota_media_dos_usuarios  nota_aparicoes_nos_usuarios  \
# filmeId
# 110                     5.000000                            3
# 50                      4.666667                            3
# 1                       4.500000                            2
# 1035                    4.500000                            2
# 786                     4.500000                            2
# 785                     4.500000                            2
# 1210                    4.500000                            2
# 1270                    4.500000                            2
# 733                     4.500000                            2
# 1307                    4.500000                            2
# 1407                    4.500000                            2
# 62                      4.500000                            2
# 316                     4.500000                            2
# 339                     4.500000                            2
# ...
